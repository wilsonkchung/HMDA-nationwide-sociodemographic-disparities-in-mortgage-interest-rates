# %%
import pandas as pd

import statsmodels.formula.api as smf

# %%
df = pd.read_csv("selected_features_dataset_fromStep2.csv")
# Out:
# /var/folders/v5/853tm03d4ds4l0z_4qjrndh40000gn/T/ipykernel_2925/1279354159.py:1: DtypeWarning: Columns (4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("selected_features_dataset_fromStep2.csv")

# %%
df.shape
# Out:
# (7059354, 18)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#         derived_ethnicity derived_race derived_sex  loan_amount  \
# 0  Not Hispanic or Latino        White      Female     655000.0
# 1  Not Hispanic or Latino        White       Joint     785000.0
# 2  Not Hispanic or Latino        White      Female     515000.0
# 3                   Joint        White       Joint     705000.0
# 4  Not Hispanic or Latino        White      Female     305000.0
#
#   loan_to_value_ratio interest_rate total_loan_costs property_value  income  \
# 0              76.471           5.0          8966.72       865000.0   228.0
# 1                90.0         5.375          9895.94       875000.0   158.0
# 2                80.0         3.375          4925.59       645000.0   105.0
# 3                80.0           6.5           5976.0       895000.0   194.0
# 4              34.884          3.75           4445.0       865000.0   230.0
#
#   debt_to_income_ratio  applicant_credit_score_type  applicant_ethnicity-1  \
# 0             30%-<36%                            2                    2.0
# 1                   42                            3                    2.0
# 2                  NaN                            2                    2.0
# 3                   41                            9                    2.0
# 4                  NaN                            9                    2.0
#
#    applicant_ethnicity_observed  applicant_race-1  applicant_race_observed  \
# 0                             2               5.0                        2
# 1                             2               5.0                        2
# 2                             2               5.0                        2
# 3                             2               5.0                        2
# 4                             2               5.0                        2
#
#    applicant_sex  applicant_sex_observed applicant_age
# 0              2                       2         25-34
# 1              1                       2         35-44
# 2              2                       2         25-34
# 3              2                       2         25-34
# 4              2                       2         25-34

# %%
model = smf.ols(
    formula="""
    interest_rate ~
    C(applicant_race_1)
    + C(applicant_ethnicity_1)
    + C(applicant_sex)
    + log_loan_amount
    + log_income
    + debt_to_income_ratio
    + loan_to_value_ratio
    + loan_term
    + C(loan_type)
    + C(loan_purpose)
    + C(state_code)
    + C(year)
    """,
    data=df
).fit(cov_type="HC3")  # robust SEs (important)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'year' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model = smf.ols(
#       2     formula="""
#       3     interest_rate ~
#       4     C(applicant_race_1)
#       5     + C(applicant_ethnicity_1)
#       6     + C(applicant_sex)
#       7     + log_loan_amount
#       8     + log_income
#       9     + debt_to_income_ratio
#      10     + loan_to_value_ratio
#      11     + loan_term
#      12     + C(loan_type)
#      13     + C(loan_purpose)
#      14     + C(state_code)
#      15     + C(year)
#      16     """,
#      17     data=df
#      18 ).fit(cov_type="HC3")  # robust SEs (important)
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/statsmodels/base/model.py:203, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     200 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     201     missing = 'raise'
# --> 203 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                           missing=missing)
#     205 ((endog, exog), missing_idx, design_info) = tmp
#     206 max_endog = cls._formula_max_endog
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/statsmodels/formula/formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/highlevel.py:319, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     309 """Construct two design matrices given a formula_like and data.
#     310
#     311 This function is identical to :func:`dmatrix`, except that it requires
#    (...)    316 See :func:`dmatrix` for details.
#     317 """
#     318 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 319 (lhs, rhs) = _do_highlevel_design(
#     320     formula_like, data, eval_env, NA_action, return_type
#     321 )
#     322 if lhs.shape[1] == 0:
#     323     raise PatsyError("model is missing required outcome variables")
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/highlevel.py:164, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     161 def data_iter_maker():
#     162     return iter([data])
# --> 164 design_infos = _try_incr_builders(
#     165     formula_like, data_iter_maker, eval_env, NA_action
#     166 )
#     167 if design_infos is not None:
#     168     return build_design_matrices(
#     169         design_infos, data, NA_action=NA_action, return_type=return_type
#     170     )
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/highlevel.py:56, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      54 if isinstance(formula_like, ModelDesc):
#      55     assert isinstance(eval_env, EvalEnvironment)
# ---> 56     return design_matrix_builders(
#      57         [formula_like.lhs_termlist, formula_like.rhs_termlist],
#      58         data_iter_maker,
#      59         eval_env,
#      60         NA_action,
#      61     )
#      62 else:
#      63     return None
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/build.py:746, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     743 factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#     744 # Now all the factors have working eval methods, so we can evaluate them
#     745 # on some data to find out what type of data they return.
# --> 746 (num_column_counts, cat_levels_contrasts) = _examine_factor_types(
#     747     all_factors, factor_states, data_iter_maker, NA_action
#     748 )
#     749 # Now we need the factor infos, which encapsulate the knowledge of
#     750 # how to turn any given factor into a chunk of data:
#     751 factor_infos = {}
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/build.py:491, in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     489 for data in data_iter_maker():
#     490     for factor in list(examine_needed):
# --> 491         value = factor.eval(factor_states[factor], data)
#     492         if factor in cat_sniffers or guess_categorical(value):
#     493             if factor not in cat_sniffers:
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/eval.py:599, in EvalFactor.eval(self, memorize_state, data)
#     598 def eval(self, memorize_state, data):
# --> 599     return self._eval(memorize_state["eval_code"], memorize_state, data)
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/eval.py:582, in EvalFactor._eval(self, code, memorize_state, data)
#     580 def _eval(self, code, memorize_state, data):
#     581     inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 582     return call_and_wrap_exc(
#     583         "Error evaluating factor",
#     584         self,
#     585         memorize_state["eval_env"].eval,
#     586         code,
#     587         inner_namespace=inner_namespace,
#     588     )
#
# File ~/Documents/GitHub/hmda-mortgage-rates-sociodemographic-disparities-analysis/.venv/lib/python3.13/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41 except Exception as e:
#      42     new_exc = PatsyError("%s: %s: %s" % (msg, e.__class__.__name__, e), origin)
# ---> 43     raise new_exc from e
#
# PatsyError: Error evaluating factor: NameError: name 'year' is not defined
#     interest_rate ~     C(applicant_race_1)     + C(applicant_ethnicity_1)     + C(applicant_sex)     + log_loan_amount     + log_income     + debt_to_income_ratio     + loan_to_value_ratio     + loan_term     + C(loan_type)     + C(loan_purpose)     + C(state_code)     + C(year)
#                                                                                                                                                                                                                                                                                  ^^^^^^^

# %%
model
